# %%
# !pip install ultralytics
# !wandb disabled
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.6 MB/s eta 0:00:0000:01
# ...
# W&B disabled.

# %%
# !yolo train model=yolov8l.pt data=/kaggle/input/fire-detection/Fire-Detection/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100%|███████████████████████████████████████| 83.7M/83.7M [00:00<00:00, 233MB/s]
# Ultralytics 8.3.168 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
